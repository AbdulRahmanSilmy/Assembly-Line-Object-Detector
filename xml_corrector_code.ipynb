# %%
#make sure the file path 'images.zip' below is right for your computer 
import zipfile
with zipfile.ZipFile('images.zip', 'r') as zip_ref:
    zip_ref.extractall('')

# %%
from datacorrector import data_corrector as dc

# %%
help(dc)
# Out:
# Help on class data_corrector in module datacorrector:
#
# class data_corrector(builtins.object)
#  |  data_corrector(folderpath)
#  |
#  |  A class that corrects data based on the filename and xml content
#  |  ...
#  |
#  |
#  |
#  |
#  |  Attributes
#  |    ------------
#  |    folderpath : str
#  |      A string that contains the path of the folder containing both train and test images.
#  |
#  |    test count: int
#  |      The number of errors found in the test data
#  |
#  |    train count: int
#  |      The number of errors found in the train data
#  |
#  |    test change: list
#  |      Nested list implying the changes made to the test data. The left element is the original and the right element is the change.
#  |
#  |    train change: list
#  |      Nested list implying the changes made to the train data. The left element is the original and the right element is the change.
#  |
#  |
#  |
#  |
#  |    Methods
#  |    -----------
#  |    correct()
# ...

# %%
#make sure the file path '/content/images' below is right for your computer 
fldr_crt=dc('/content/images')
fldr_crt.correct()
# Out:
# correcting test data:
# 43 errors have been found
#
# correcting train data:
# Filename graycoverpcb_1.xml in folder /content/images/train has unequal number of classes present in image and xml file
# Manual inspection and changing of data is required
# 189 errors have been found
#
# total number of errors:  232

# %%
fldr_crt.train_changes
# Out:
# [[[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [['Gray Back Cover'], ['Grey Back Cover']],
#  [[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
# ...

# %%
fldr_crt.test_changes
# Out:
# [[[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [['Gray Front Cover'], ['Grey Front Cover']],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [[], []],
#  [['Gray Back Cover'], ['Grey Back Cover']],
#  [[], []],
#  [[], []],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [['Red Front Cover'], ['Grey Front Cover']],
#  [['Gray Front Cover'], ['Grey Front Cover']],
# ...
